# %% [markdown]
# # MIT Book Reading Notes
# ### Chapter1-3 0909 written by hhshhd
#
# ## Getting Started
#
# What a Computer can do?
# -Performs calculation.
# -Remembers the results of those calculations.
# Types of Knowledge
# -Declarative knowledge
# -Imperative knowledge
# Algorithm
# > Note that the description of the method is a sequence of simple steps, together with a flow of control that specifies when each step is to be executed.
#
# Types of computer
# -fixed- program computers
# -stored-program computer
# Programming language
# -to create recipes
# Syntax of a language
# -defines which strings of characters and symbols are well formed.
# Static semantics
# -defines which syntactically valid strings have a meaning.
# Semantics of a language
# -associates a meaning with each syntactically correct string of symbols that has no static semantic errors.
# ## Introduction to python
#
# ### the basic elements of python
# A command
# -often called a statement,
# -instructs the interpreter to do something.
# #### Objects, expressions, and Numerical Types
# Objects
# -the core things that Python programs manipulate.
# Type
# -either scalar or non-scalar
# >Scalar objects are indivisible..
#
# Expressions
# -Objects and operators can be combined to form
# #### Variable and Assignment
# Variables
# -provide a way to associate names with objects.
# -just a name
# > An assignment statement associates the name to the left of the = symbol with the object denoted by the expression to the right of the =.
#
# Comments.
# -Another good way to enhance the readability of code is to add
#
# #### IDLE
# Most programmers prefer to use some sort of text editor that is part of an integrated development environment (IDE).
# ### Branchinng Programs
# Straight- line programs.
# -The kinds of computations we have been looking at thus far are called
# Branching programs
# -The simplest branching statement is a *conditional*.
# Indentation
# -is semantically meaningful in Python.
# ### Strings and Input
# The length of a string
# -can be found using the len function.
# Indexing
# -can be used to extract individual characters from a string.
# Slicing
# -is used to extract substrings of arbitrary length.
# #### Input
# > Type conversions (also called type casts) are used often in Python code.
# ### Iteration
#
# ## Some Simple Numerical Programs
#
# ### Exhausive Enumeration
# Decrementing function.
# -Whenever you write a loop, you should think about an appropriate
# Exhaustive enumeration.
# -The algorithmic technique used in this program is a variant of guess and check called
# ### For Loops
#
# ### Approximate Solutions and Bisection Search
#
# ### A few Words About Using Floats
#
# ### Newton-Raphson
# > A polynomial with one variable (by convention, we will write the variable as x) is either zero or the sum of a finite number of nonzero terms, e.g., 3x2 + 2x + 3. Each term, e.g., 3x2, consists of a constant (the coefficient of the term, 3 in this case) multiplied by the variable (x in this case) raised to a nonnegative integer exponent (2 in this case). The exponent on a variable in a term is called the degree of that term. The degree of a polynomial is the largest degree of any single term. Some examples are, 3 (degree 0), 2.5x + 12 (degree 1), and 3x2
# (degree 2). In contrast, 2/x and x0.5 are not polynomials.
